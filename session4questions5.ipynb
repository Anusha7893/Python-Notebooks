# %% [markdown]
# <a href="https://colab.research.google.com/github/Anusha7893/Python-Notebooks/blob/main/session4questions5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![WhatsApp Image 2024-05-14 at 15.13.06.jpeg](data:image/jpeg;base64,...)

# %%
# Solution

A = int(input("Enter first number: "))
B = int(input("Enter second number: "))

compare = A > 0 and B > 0


print(compare)

# %% [markdown]
# ![WhatsApp Image 2024-05-14 at 15.13.05.jpeg](data:image/jpeg;base64,...)

# %%
# Solution

M = int(input("Enter marks for Maths: "))
P = int(input("Enter marks for Physics: "))
C = int(input("Enter marks for Chemistry: "))


compare = M >= 70 and B >= 60 and C >= 60
sum = (M + P + C) >= 180


print(compare or sum)
# Out:
# Enter marks for Maths: 0
# Enter marks for Physics: 100
# Enter marks for Chemistry: 100
# True

# %% [markdown]
# ![WhatsApp Image 2024-05-14 at 15.13.05 (2).jpeg](data:image/jpeg;base64,...)

# %%
# Solution

A = input("Enter first word: ")
B = input("Enter second word: ")
C = input("Enter third word: ")

compare = A == "woman" or B == "woman" or C == "woman"


print(compare)
# Out:
# Enter first word: girl
# Enter second word: boy
# Enter third word: woman
# True

# %% [markdown]
# ![WhatsApp Image 2024-05-14 at 15.13.05 (1).jpeg](data:image/jpeg;base64,...)

# %%
# Solution

A = int(input("Enter the age: "))
S = input("Enter guardian status: ")
age = 12 < A < 60
status = S == "yes"

print( age or status)
# Out:
# Enter the age: 61
# Enter guardian status: yes
# True

# %% [markdown]
# ![WhatsApp Image 2024-05-14 at 15.13.04.jpeg](data:image/jpeg;base64,...)

# %%
# Solution

# %% [markdown]
# ![WhatsApp Image 2024-05-14 at 15.13.04 (1).jpeg](data:image/jpeg;base64,...)

# %%
# Solution

# %% [markdown]
# ![WhatsApp Image 2024-05-14 at 15.13.03.jpeg](data:image/jpeg;base64,...)

# %%
# Solution

# %% [markdown]
# ![WhatsApp Image 2024-05-14 at 15.13.03 (1).jpeg](data:image/jpeg;base64,...)

# %%
# Solution

# %% [markdown]
# ![WhatsApp Image 2024-05-14 at 15.13.02.jpeg](data:image/jpeg;base64,...)

# %%
# Solution

# %% [markdown]
# ![WhatsApp Image 2024-05-14 at 15.13.02 (1).jpeg](data:image/jpeg;base64,...)

# %%
# Solution
