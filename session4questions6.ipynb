# %% [markdown]
# <a href="https://colab.research.google.com/github/Anusha7893/Python-Notebooks/blob/main/session4questions6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![WhatsApp Image 2024-05-14 at 15.17.28.jpeg](data:image/jpeg;base64,...)

# %%
# Solution

# %% [markdown]
# ![WhatsApp Image 2024-05-14 at 15.17.28 (2).jpeg](data:image/jpeg;base64,...)

# %%
# Solution

# %% [markdown]
# ![WhatsApp Image 2024-05-14 at 15.17.28 (1).jpeg](data:image/jpeg;base64,...)

# %%
# Solution

# %% [markdown]
# ![WhatsApp Image 2024-05-14 at 15.17.27.jpeg](data:image/jpeg;base64,...)

# %%
# Solution

# %% [markdown]
# ![WhatsApp Image 2024-05-14 at 15.17.27 (2).jpeg](data:image/jpeg;base64,...)

# %%
# Solution

# %% [markdown]
# ![WhatsApp Image 2024-05-14 at 15.17.27 (1).jpeg](data:image/jpeg;base64,...)

# %%
# Solution

# %% [markdown]
# ![WhatsApp Image 2024-05-14 at 15.17.26.jpeg](data:image/jpeg;base64,...)

# %%
# Solution

# %% [markdown]
# ![WhatsApp Image 2024-05-14 at 15.17.25.jpeg](data:image/jpeg;base64,...)

# %%
# Solution

# %% [markdown]
# ![WhatsApp Image 2024-05-14 at 15.17.25 (1).jpeg](data:image/jpeg;base64,...)

# %%
# Solution

# %% [markdown]
# ![WhatsApp Image 2024-05-14 at 15.17.26 (2).jpeg](data:image/jpeg;base64,...)

# %%
# Solution

# %% [markdown]
# ![WhatsApp Image 2024-05-14 at 15.17.26 (1).jpeg](data:image/jpeg;base64,...)

# %%
# Solution
